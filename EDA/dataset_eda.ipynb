# %% [markdown]
# # Importing necessary libraries

# %%
import os 
import pandas as pd

# %% [markdown]
# # Load and Setup Dataset

# %%
df_whole = pd.read_csv("Dataset.csv")
df_whole.head()
# Out:
#    observation_id   photo_id                       image_id license_code  \
# 0       341194952  621071156  obs_341194952_photo_621071156        cc-by
# 1       341194952  621071168  obs_341194952_photo_621071168        cc-by
# 2       341194952  621071177  obs_341194952_photo_621071177        cc-by
# 3       341194952  621071190  obs_341194952_photo_621071190        cc-by
# 4       341194952  621071213  obs_341194952_photo_621071213        cc-by
#
#                                           square_url  \
# 0  https://inaturalist-open-data.s3.amazonaws.com...
# 1  https://inaturalist-open-data.s3.amazonaws.com...
# 2  https://inaturalist-open-data.s3.amazonaws.com...
# 3  https://inaturalist-open-data.s3.amazonaws.com...
# 4  https://inaturalist-open-data.s3.amazonaws.com...
#
#                                           medium_url  \
# 0  https://inaturalist-open-data.s3.amazonaws.com...
# 1  https://inaturalist-open-data.s3.amazonaws.com...
# ...

# %%
len(df_whole)
# Out:
# 24807

# %%
df_whole.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 24807 entries, 0 to 24806
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   observation_id           24807 non-null  int64
#  1   photo_id                 24807 non-null  int64
#  2   image_id                 24807 non-null  str
#  3   license_code             24807 non-null  str
#  4   square_url               24807 non-null  str
#  5   medium_url               24807 non-null  str
#  6   large_url                24807 non-null  str
#  7   original_url             24807 non-null  str
#  8   scientific_name          24807 non-null  str
#  9   common_name              24807 non-null  str
#  10  taxon_rank               24807 non-null  str
#  11  ob_license_code          24807 non-null  str
#  12  quality_grade            24807 non-null  str
#  13  uri                      24807 non-null  str
#  14  pred_prey                24807 non-null  str
# ...

# %%
df_whole.isna().sum()
# Out:
# observation_id             0
# photo_id                   0
# image_id                   0
# license_code               0
# square_url                 0
# medium_url                 0
# large_url                  0
# original_url               0
# scientific_name            0
# common_name                0
# taxon_rank                 0
# ob_license_code            0
# quality_grade              0
# uri                        0
# pred_prey                  0
# special_type_of_feeding    0
# taxon_kingdom              0
# taxon_phylum               0
# taxon_class                0
# taxon_order                0
# taxon_family               0
# taxon_genus                0
# taxon_species              0
# dtype: int64
