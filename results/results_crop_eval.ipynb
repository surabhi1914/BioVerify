# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # LOAD FILE

# %%
file_path = "results_crop.csv"

df = pd.read_csv(file_path)

print("Shape:", df.shape)
print("Columns:", df.columns.tolist())
# Out:
# Shape: (373730, 25)
# Columns: ['crop_file', 'crop_file_path', 'image_id', 'Falsely identified', 'box_num', 'species', 'User_classified', 'same_species?', 'My analysis', 'common_name', 'kingdom', 'user_kingdom', 'phylum', 'user_phylum', 'class', 'user_class', 'order', 'user_order', 'family', 'user_family', 'genus', 'user_genus', 'score', 'top_no', 'topk_predictions_json']

# %% [markdown]
# # HELPER FUNCTIONS

# %%
def normalize_text(x):
    """
    Normalize text for comparison:
    - handle NaN
    - convert to string
    - strip spaces
    - lowercase
    - collapse repeated spaces
    """
    if pd.isna(x):
        return np.nan
    x = str(x).strip().lower()
    x = " ".join(x.split())
    if x in ["", "nan", "none", "null"]:
        return np.nan
    return x

# %%
# def normalize_bool_false(series):
#     """
#     Robust handling in case same_species? is boolean or string.
#     Returns True for rows where same_species is False.
#     """
#     s = series.astype(str).str.strip().str.lower()
#     return s.isin(["false", "0", "no"])

# %%
def normalize_bool_true(series):
    """
    Robust handling in case same_species? is boolean or string.
    Returns True for rows where same_species is True.
    """
    s = series.astype(str).str.strip().str.lower()
    return s.isin(["true", "1", "yes"])

# %% [markdown]
# # KEEP ONLY same_species == False

# %%
true_df = df[normalize_bool_true(df["same_species?"])].copy()

print("\nRows with same_species == True:", len(true_df))
print("Unique image_ids in true set:", true_df["image_id"].nunique())
# Out:
# Rows with same_species == True: 39177
# Unique image_ids in true set: 17840

# %%
false_df = df[~df["image_id"].isin(true_df["image_id"])].copy()
print("\nRows with same_species == False:", len(false_df))
print("Unique image_ids in false set:", false_df["image_id"].nunique())
# Out:
# Rows with same_species == False: 103945
# Unique image_ids in false set: 6963

# %% [markdown]
# # DEFINE TAXONOMIC LEVEL PAIRS

# %%
level_pairs = {
    "kingdom": ("kingdom", "user_kingdom"),
    "phylum": ("phylum", "user_phylum"),
    "class": ("class", "user_class"),
    "order": ("order", "user_order"),
    "family": ("family", "user_family"),
    "genus": ("genus", "user_genus"),
    "species": ("species", "User_classified"),
}

# %%
# Check required columns exist
missing_cols = []
for level, (pred_col, user_col) in level_pairs.items():
    if pred_col not in false_df.columns:
        missing_cols.append(pred_col)
    if user_col not in false_df.columns:
        missing_cols.append(user_col)

if missing_cols:
    raise ValueError(f"Missing required columns: {sorted(set(missing_cols))}")

# %%
# Check required columns exist
missing_cols = []
for level, (pred_col, user_col) in level_pairs.items():
    if pred_col not in df.columns:
        missing_cols.append(pred_col)
    if user_col not in df.columns:
        missing_cols.append(user_col)

if missing_cols:
    raise ValueError(f"Missing required columns: {sorted(set(missing_cols))}")

# %%
# Check required columns exist
missing_cols = []
for level, (pred_col, user_col) in level_pairs.items():
    if pred_col not in false_df.columns:
        missing_cols.append(pred_col)
    if user_col not in false_df.columns:
        missing_cols.append(user_col)

if missing_cols:
    raise ValueError(f"Missing required columns: {sorted(set(missing_cols))}")

# %% [markdown]
# # NORMALIZE VALUES + CREATE ROW-LEVEL MATCH COLUMNS

# %%
for level, (pred_col, user_col) in level_pairs.items():
    false_df[f"{level}_pred_norm"] = false_df[pred_col].apply(normalize_text)
    false_df[f"{level}_user_norm"] = false_df[user_col].apply(normalize_text)

    # row-level exact match only if both are present
    false_df[f"{level}_row_match"] = (
        false_df[f"{level}_pred_norm"].notna()
        & false_df[f"{level}_user_norm"].notna()
        & (false_df[f"{level}_pred_norm"] == false_df[f"{level}_user_norm"])
    )

# %%
for level, (pred_col, user_col) in level_pairs.items():
    df[f"{level}_pred_norm"] = df[pred_col].apply(normalize_text)
    df[f"{level}_user_norm"] = df[user_col].apply(normalize_text)

    # row-level exact match only if both are present
    df[f"{level}_row_match"] = (
        df[f"{level}_pred_norm"].notna()
        & df[f"{level}_user_norm"].notna()
        & (df[f"{level}_pred_norm"] == df[f"{level}_user_norm"])
    )

# %%
for level, (pred_col, user_col) in level_pairs.items():
    true_df[f"{level}_pred_norm"] = true_df[pred_col].apply(normalize_text)
    true_df[f"{level}_user_norm"] = true_df[user_col].apply(normalize_text)

    # row-level exact match only if both are present
    true_df[f"{level}_row_match"] = (
        true_df[f"{level}_pred_norm"].notna()
        & true_df[f"{level}_user_norm"].notna()
        & (true_df[f"{level}_pred_norm"] == true_df[f"{level}_user_norm"])
    )

# %% [markdown]
# # If one of the rows for an image_id matches, count image as matched

# %%
agg_dict = {}
for level in level_pairs.keys():
    agg_dict[f"{level}_row_match"] = "max"   # True if any row matches

image_true_level = true_df.groupby("image_id", as_index=False).agg(agg_dict)

# Rename columns for readability
image_true_level = image_true_level.rename(
    columns={f"{level}_row_match": f"{level}_image_match" for level in level_pairs.keys()}
)

print("\nImage-true level match table:")

print(image_true_level.head())
# Out:
# Image-true level match table:
#                         image_id  kingdom_image_match  phylum_image_match  \
# 0   obs_10003229_photo_114145431                 True                True
# 1  obs_100125424_photo_167070208                 True                True
# 2  obs_100125424_photo_167070213                 True                True
# 3  obs_100126056_photo_167071230                 True                True
# 4  obs_100126348_photo_167071805                 True                True
#
#    class_image_match  order_image_match  family_image_match  \
# 0               True               True                True
# 1               True               True                True
# 2               True               True                True
# 3               True               True                True
# 4               True               True                True
#
#    genus_image_match  species_image_match
# 0               True                 True
# 1               True                 True
# 2               True                 True
# 3               True                 True
# 4               True                 True

# %%
agg_dict = {}
for level in level_pairs.keys():
    agg_dict[f"{level}_row_match"] = "max"   # True if any row matches

image_false_level = false_df.groupby("image_id", as_index=False).agg(agg_dict)

# Rename columns for readability
image_false_level = image_false_level.rename(
    columns={f"{level}_row_match": f"{level}_image_match" for level in level_pairs.keys()}
)

print("\nImage-false level match table:")
print(image_false_level.head())
# Out:
# Image-false level match table:
#                         image_id  kingdom_image_match  phylum_image_match  \
# 0  obs_100052837_photo_166933111                 True                True
# 1  obs_100052837_photo_166933119                 True                True
# 2  obs_100052837_photo_166933123                 True                True
# 3  obs_100053359_photo_166934121                 True                True
# 4  obs_100053359_photo_166934128                 True                True
#
#    class_image_match  order_image_match  family_image_match  \
# 0               True               True               False
# 1               True               True                True
# 2               True               True               False
# 3               True               True                True
# 4               True               True                True
#
#    genus_image_match  species_image_match
# 0              False                False
# 1              False                False
# 2              False                False
# 3              False                False
# 4              False                False

# %%
agg_dict = {}
for level in level_pairs.keys():
    agg_dict[f"{level}_row_match"] = "max"   # True if any row matches

image_whole_level = df.groupby("image_id", as_index=False).agg(agg_dict)

# Rename columns for readability
image_whole_level = image_whole_level.rename(
    columns={f"{level}_row_match": f"{level}_image_match" for level in level_pairs.keys()}
)

print("\nImage-level match table:")
print(image_whole_level)
# Out:
# Image-level match table:
#                             image_id  kingdom_image_match  phylum_image_match  \
# 0       obs_10003229_photo_114145431                 True                True
# 1      obs_100052837_photo_166933111                 True                True
# 2      obs_100052837_photo_166933119                 True                True
# 3      obs_100052837_photo_166933123                 True                True
# 4      obs_100053359_photo_166934121                 True                True
# ...                              ...                  ...                 ...
# 24798   obs_99990955_photo_166796310                 True                True
# 24799   obs_99990955_photo_166796399                 True                True
# 24800   obs_99990955_photo_166796459                 True                True
# 24801   obs_99990956_photo_166796339                 True                True
# 24802   obs_99990956_photo_166796345                 True                True
#
#        class_image_match  order_image_match  family_image_match  \
# 0                   True               True                True
# 1                   True               True               False
# 2                   True               True                True
# 3                   True               True               False
# 4                   True               True                True
# ...                  ...                ...                 ...
# 24798               True               True                True
# 24799               True               True                True
# 24800               True               True                True
# 24801               True               True                True
# 24802               True               True                True
#
#        genus_image_match  species_image_match
# 0                   True                 True
# 1                  False                False
# 2                  False                False
# 3                  False                False
# 4                  False                False
# ...                  ...                  ...
# 24798               True                False
# 24799               True                False
# 24800               True                False
# 24801              False                False
# 24802              False                False
#
# [24803 rows x 8 columns]

# %% [markdown]
# # ACCURACY BY TAXONOMIC LEVEL

# %%
accuracy_rows = []
n_images = len(image_false_level)

for level in level_pairs.keys():
    if level == "species": continue  # Skip species level for accuracy calculation
    match_col = f"{level}_image_match"
    matched_images = image_false_level[match_col].sum()
    accuracy = matched_images / n_images if n_images > 0 else np.nan

    accuracy_rows.append({
        "Level": level,
        "Matched_image_ids": int(matched_images),
        "Total_image_ids": int(n_images),
        "Accuracy": accuracy,
        "Accuracy_%": round(accuracy * 100, 2) if pd.notna(accuracy) else np.nan
    })

accuracy_false_df = pd.DataFrame(accuracy_rows)


print("\n=== Accuracy by Taxonomic Level (Image-level) for falsely predicted images ===")
print(accuracy_false_df.sort_values("Accuracy", ascending=False))
# Out:
# === Accuracy by Taxonomic Level (Image-level) for falsely predicted images ===
#      Level  Matched_image_ids  Total_image_ids  Accuracy  Accuracy_%
# 0  kingdom               6512             6963  0.935229       93.52
# 1   phylum               6258             6963  0.898751       89.88
# 2    class               5022             6963  0.721241       72.12
# 3    order               4206             6963  0.604050       60.40
# 4   family               3952             6963  0.567571       56.76
# 5    genus               2329             6963  0.334482       33.45

# %%
accuracy_rows = []
n_images = len(image_true_level)

for level in level_pairs.keys():
    # if level == "species": continue  # Skip species level for accuracy calculation
    match_col = f"{level}_image_match"
    matched_images = image_true_level[match_col].sum()
    accuracy = matched_images / n_images if n_images > 0 else np.nan

    accuracy_rows.append({
        "Level": level,
        "Matched_image_ids": int(matched_images),
        "Total_image_ids": int(n_images),
        "Accuracy": accuracy,
        "Accuracy_%": round(accuracy * 100, 2) if pd.notna(accuracy) else np.nan
    })

accuracy_true_df = pd.DataFrame(accuracy_rows)


print("\n=== Accuracy by Taxonomic Level (Image-level) for truly predicted images ===")
print(accuracy_true_df.sort_values("Accuracy", ascending=False))
# Out:
# === Accuracy by Taxonomic Level (Image-level) for truly predicted images ===
#      Level  Matched_image_ids  Total_image_ids  Accuracy  Accuracy_%
# 0  kingdom              17840            17840  1.000000      100.00
# 1   phylum              17840            17840  1.000000      100.00
# 6  species              17840            17840  1.000000      100.00
# 5    genus              17837            17840  0.999832       99.98
# 4   family              17433            17840  0.977186       97.72
# 3    order              16512            17840  0.925561       92.56
# 2    class              16429            17840  0.920908       92.09

# %%
accuracy_rows = []
n_images = len(image_whole_level)

for level in level_pairs.keys():
    # if level == "species": continue  # Skip species level for accuracy calculation
    match_col = f"{level}_image_match"
    matched_images = image_whole_level[match_col].sum()
    accuracy = matched_images / n_images if n_images > 0 else np.nan

    accuracy_rows.append({
        "Level": level,
        "Matched_image_ids": int(matched_images),
        "Total_image_ids": int(n_images),
        "Accuracy": accuracy,
        "Accuracy_%": round(accuracy * 100, 2) if pd.notna(accuracy) else np.nan
    })

accuracy_whole_df = pd.DataFrame(accuracy_rows)

print("\n=== Accuracy by Taxonomic Level (Image-level) ===")
print(accuracy_whole_df.sort_values("Accuracy", ascending=False))
# Out:
# === Accuracy by Taxonomic Level (Image-level) ===
#      Level  Matched_image_ids  Total_image_ids  Accuracy  Accuracy_%
# 0  kingdom              24352            24803  0.981817       98.18
# 1   phylum              24098            24803  0.971576       97.16
# 2    class              21451            24803  0.864855       86.49
# 4   family              21420            24803  0.863605       86.36
# 3    order              20736            24803  0.836028       83.60
# 5    genus              20167            24803  0.813087       81.31
# 6  species              17840            24803  0.719268       71.93

# %%
# accuracy_df.to_csv("taxonomy_accuracy_by_level.csv", index=False)
# image_level.to_csv("image_level_taxonomy_match.csv", index=False)

# print("\nSaved:")
# print("- taxonomy_accuracy_by_level.csv")
# print("- image_level_taxonomy_match.csv")

# %% [markdown]
# # Visualization

# %% [markdown]
# ## BAR CHART OF ACCURACY BY LEVEL

# %%
plt.figure(figsize=(10, 6))
plt.bar(accuracy_false_df["Level"], accuracy_false_df["Accuracy_%"])
plt.ylabel("Accuracy (%)")
plt.xlabel("Taxonomic level")
plt.title("Image-level match accuracy by taxonomic level\n(Falsely predicted images)")
plt.ylim(0, 100)

for i, v in enumerate(accuracy_false_df["Accuracy_%"]):
    plt.text(i, v + 1, f"{v:.2f}%", ha="center")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(accuracy_true_df["Level"], accuracy_true_df["Accuracy_%"])
plt.ylabel("Accuracy (%)")
plt.xlabel("Taxonomic level")
plt.title("Image-level match accuracy by taxonomic level\n(Truly predicted images)")
plt.ylim(0, 100)

for i, v in enumerate(accuracy_true_df["Accuracy_%"]):
    plt.text(i, v + 1, f"{v:.2f}%", ha="center")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(accuracy_whole_df["Level"], accuracy_whole_df["Accuracy_%"])
plt.ylabel("Accuracy (%)")
plt.xlabel("Taxonomic level")
plt.title("Image-level match accuracy by taxonomic level\n(all images)")
plt.ylim(0, 100)

for i, v in enumerate(accuracy_whole_df["Accuracy_%"]):
    plt.text(i, v + 1, f"{v:.1f}%", ha="center")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## MATCH COUNTS BY LEVEL

# %%
plt.figure(figsize=(10, 6))
plt.bar(accuracy_false_df["Level"], accuracy_false_df["Matched_image_ids"])
plt.ylabel("Number of matched image_ids")
plt.xlabel("Taxonomic level")
plt.title("Matched image_ids by taxonomic level\n(Falsely predicted images)")

for i, v in enumerate(accuracy_false_df["Matched_image_ids"]):
    plt.text(i, v + 0.2, str(v), ha="center")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(accuracy_whole_df["Level"], accuracy_whole_df["Matched_image_ids"])
plt.ylabel("Number of matched image_ids")
plt.xlabel("Taxonomic level")
plt.title("Matched image_ids by taxonomic level\n(only same_species = False)")

for i, v in enumerate(accuracy_whole_df["Matched_image_ids"]):
    plt.text(i, v + 0.2, str(v), ha="center")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(accuracy_true_df["Level"], accuracy_true_df["Matched_image_ids"])
plt.ylabel("Number of matched image_ids")
plt.xlabel("Taxonomic level")
plt.title("Matched image_ids by taxonomic level\n(Truly predicted images)")

for i, v in enumerate(accuracy_true_df["Matched_image_ids"]):
    plt.text(i, v + 0.2, str(v), ha="center")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## IMAGE-LEVEL MATCH HEATMAP

# %%
# heatmap_df = image_level.set_index("image_id").astype(int)

# plt.figure(figsize=(12, max(6, len(heatmap_df) * 0.25)))
# plt.imshow(heatmap_df, aspect="auto")
# plt.colorbar(label="Match (1 = yes, 0 = no)")
# plt.xticks(
#     ticks=range(len(heatmap_df.columns)),
#     labels=[c.replace("_image_match", "") for c in heatmap_df.columns],
#     rotation=45
# )
# plt.yticks(ticks=range(len(heatmap_df.index)), labels=heatmap_df.index)
# plt.title("Image-level taxonomy match heatmap\n(only same_species = False)")
# plt.tight_layout()
# plt.show()

# %%
# heatmap_df = image_whole_level.set_index("image_id").astype(int)

# plt.figure(figsize=(12, max(6, len(heatmap_df) * 0.25)))
# plt.imshow(heatmap_df, aspect="auto")
# plt.colorbar(label="Match (1 = yes, 0 = no)")
# plt.xticks(
#     ticks=range(len(heatmap_df.columns)),
#     labels=[c.replace("_image_match", "") for c in heatmap_df.columns],
#     rotation=45
# )
# plt.yticks(ticks=range(len(heatmap_df.index)), labels=heatmap_df.index)
# plt.title("Image-level taxonomy match heatmap\n(only same_species = False)")
# plt.tight_layout()
# plt.show()

# %% [markdown]
# # Summary

# %%
print("\n=== Summary ===")
n_images = len(image_false_level)
best_level = accuracy_false_df.sort_values("Accuracy", ascending=False).iloc[0]
worst_level = accuracy_false_df.sort_values("Accuracy", ascending=True).iloc[0]

print(f"Total false-species image_ids analyzed: {n_images}")
print(f"Highest image-level match: {best_level['Level']} ({best_level['Accuracy_%']}%)")
print(f"Lowest image-level match: {worst_level['Level']} ({worst_level['Accuracy_%']}%)")
# Out:
# === Summary ===
# Total false-species image_ids analyzed: 6963
# Highest image-level match: kingdom (93.52%)
# Lowest image-level match: genus (33.45%)

# %%
print("\n=== Summary ===")
n_images = len(image_true_level)
best_level = accuracy_true_df.sort_values("Accuracy", ascending=False).iloc[0]
worst_level = accuracy_true_df.sort_values("Accuracy", ascending=True).iloc[0]

print(f"Total true-species image_ids analyzed: {n_images}")
print(f"Highest image-level match: {best_level['Level']} ({best_level['Accuracy_%']}%)")
print(f"Lowest image-level match: {worst_level['Level']} ({worst_level['Accuracy_%']}%)")
# Out:
# === Summary ===
# Total true-species image_ids analyzed: 17840
# Highest image-level match: kingdom (100.0%)
# Lowest image-level match: class (92.09%)

# %%
print("\n=== Summary ===")
n_images = len(image_whole_level)
best_level = accuracy_whole_df.sort_values("Accuracy", ascending=False).iloc[0]
worst_level = accuracy_whole_df.sort_values("Accuracy", ascending=True).iloc[0]

print(f"Total false-species image_ids analyzed: {n_images}")
print(f"Highest image-level match: {best_level['Level']} ({best_level['Accuracy_%']}%)")
print(f"Lowest image-level match: {worst_level['Level']} ({worst_level['Accuracy_%']}%)")
# Out:
# === Summary ===
# Total false-species image_ids analyzed: 24803
# Highest image-level match: kingdom (98.18%)
# Lowest image-level match: species (71.93%)

# %% [markdown]
# # Analysis type distribution

# %%
analysis_df = df[(df["same_species?"]==False) & df["My analysis"].notna()]
len(analysis_df["My analysis"])
# Out:
# 0

# %%
analysis_df["My analysis"].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
analysis_df["My analysis"].unique()
# Out:
# array([], dtype=float64)

# %%
analysis_df["image_box"]=analysis_df["image_id"] + "_" + analysis_df["box_num"].astype(str)
analysis_df["image_box"].head(10)
# Out:
# Series([], Name: image_box, dtype: str)

# %%
analysis_df["image_box"].unique()
# Out:
# <StringArray>
# []
# Length: 0, dtype: str

# %%
summary_dict={}


for image_box, group_df in analysis_df.groupby("image_box"):
    # print(image_box)
    # print(group_df)
    for i in range(len(group_df)-1):
        if group_df["My analysis"].iloc[i]=="Same genus but diff species":
            summary_dict["Same genus but diff species"]=summary_dict.get("Same genus but diff species",0)+1
        else:
            summary_dict[group_df["My analysis"].iloc[i]]=summary_dict.get(group_df["My analysis"].iloc[i],0)+1
print(summary_dict)
# Out:
# {}

# %%
summary_dict={}
    
for _, group_df in analysis_df.groupby("image_box"):
    if group_df["My analysis"].eq("Same genus but diff species").any():
        summary_dict["Same genus but diff species"]=summary_dict.get("Same genus but diff species",0)+1
    else:
        summary_dict[group_df["My analysis"].iloc[i]]=summary_dict.get(group_df["My analysis"].iloc[i],0)+1

print(summary_dict)
# Out:
# {}

# %%
df_summary = pd.DataFrame(
    summary_dict.items(),
    columns=["Category", "Count"]
)

# %%
total = df_summary["Count"].sum()
print("Total:", total)
df_summary["Percentage"] = (df_summary["Count"] / total) * 100

print(df_summary)
# Out:
# Total: 0
# Empty DataFrame
# Columns: [Category, Count, Percentage]
# Index: []

# %%
group_mapping = {
    "Group 1: Same genus but diff species": [
        "Same genus but diff species"
    ],
    "Group 2: Species is small part of the box": [
        "Species is small part of the box",
        "Species is small part of the box. Fungus."
    ],
    "Group 3: Species features not very clear": [
        "Species features not very clear",
        "Species is small part of the box; Species features not very clear",
        "Species is small part of the box. Fungus; Species features not very clear"
    ],
    "Group 4: Misidentified as different species": [
        "Misidentified as different species"
    ],
    "Group 5: Species not in the box": [
        "Species not in the box"
    ]
}

# -----------------------------
# 3. Compute grouped stats
# -----------------------------
rows = []

for group_name, notes in group_mapping.items():
    count = analysis_df[analysis_df["My analysis"].isin(notes)].shape[0]
    
    rows.append({
        "Group": group_name,
        "Count": count,
        "% of false": round((count / len(true_df)) * 100, 2) if len(true_df) else 0,
        "% of total": round((count / total) * 100, 2) if total else 0
    })

grouped_stats = pd.DataFrame(rows)

print(grouped_stats)
# Out:
#                                          Group  Count  % of false  % of total
# 0         Group 1: Same genus but diff species      0         0.0           0
# 1    Group 2: Species is small part of the box      0         0.0           0
# 2     Group 3: Species features not very clear      0         0.0           0
# 3  Group 4: Misidentified as different species      0         0.0           0
# 4              Group 5: Species not in the box      0         0.0           0

# %% [markdown]
# # Which category was rightly classified?

# %%
df
# Out:
#                                     crop_file  \
# 0       obs_10003229_photo_114145431_box1.jpg
# 1       obs_10003229_photo_114145431_box1.jpg
# 2       obs_10003229_photo_114145431_box1.jpg
# 3       obs_10003229_photo_114145431_box1.jpg
# 4       obs_10003229_photo_114145431_box1.jpg
# ...                                       ...
# 373725  obs_99990956_photo_166796345_box2.jpg
# 373726  obs_99990956_photo_166796345_box2.jpg
# 373727  obs_99990956_photo_166796345_box2.jpg
# 373728  obs_99990956_photo_166796345_box2.jpg
# 373729  obs_99990956_photo_166796345_box2.jpg
#
#                                            crop_file_path  \
# 0       /rs1/researchers/a/amallav/results/outputs_cro...
# 1       /rs1/researchers/a/amallav/results/outputs_cro...
# 2       /rs1/researchers/a/amallav/results/outputs_cro...
# 3       /rs1/researchers/a/amallav/results/outputs_cro...
# 4       /rs1/researchers/a/amallav/results/outputs_cro...
# ...                                                   ...
# 373725  /rs1/researchers/a/amallav/results/outputs_cro...
# 373726  /rs1/researchers/a/amallav/results/outputs_cro...
# 373727  /rs1/researchers/a/amallav/results/outputs_cro...
# 373728  /rs1/researchers/a/amallav/results/outputs_cro...
# 373729  /rs1/researchers/a/amallav/results/outputs_cro...
#
#                             image_id Falsely identified  box_num  \
# 0       obs_10003229_photo_114145431              Match        1
# 1       obs_10003229_photo_114145431              Match        1
# 2       obs_10003229_photo_114145431              Match        1
# 3       obs_10003229_photo_114145431              Match        1
# 4       obs_10003229_photo_114145431              Match        1
# ...                              ...                ...      ...
# 373725  obs_99990956_photo_166796345           No Match        2
# 373726  obs_99990956_photo_166796345           No Match        2
# 373727  obs_99990956_photo_166796345           No Match        2
# 373728  obs_99990956_photo_166796345           No Match        2
# 373729  obs_99990956_photo_166796345           No Match        2
#
#                             species           User_classified  same_species?  \
# 0                Cerocala contraria        Eudocima divitiosa          False
# 1       Chrysorithrum flavomaculata        Eudocima divitiosa          False
# 2           Ulotrichopus marmoratus        Eudocima divitiosa          False
# 3                Eudocima divitiosa        Eudocima divitiosa           True
# 4                  Eudocima colubra        Eudocima divitiosa          False
# ...                             ...                       ...            ...
# 373725      Tauraco porphyreolophus  Gallirex porphyreolophus          False
# 373726            Tauraco hartlaubi  Gallirex porphyreolophus          False
# 373727        Tauraco erythrolophus  Gallirex porphyreolophus          False
# 373728             Tauraco fischeri  Gallirex porphyreolophus          False
# 373729            Tauraco corythaix  Gallirex porphyreolophus          False
#
#         My analysis            common_name  ... order_row_match  \
# 0               NaN                    NaN  ...            True
# 1               NaN                    NaN  ...            True
# 2               NaN                    NaN  ...            True
# 3               NaN                    NaN  ...            True
# 4               NaN                    NaN  ...            True
# ...             ...                    ...  ...             ...
# 373725          NaN  Purple-crested Turaco  ...            True
# 373726          NaN      Hartlaub's Turaco  ...            True
# 373727          NaN     Red-crested Turaco  ...            True
# 373728          NaN       Fischer's turaco  ...            True
# 373729          NaN          Knysna turaco  ...            True
#
#        family_pred_norm family_user_norm family_row_match genus_pred_norm  \
# 0              erebidae         erebidae             True        cerocala
# 1              erebidae         erebidae             True   chrysorithrum
# 2              erebidae         erebidae             True    ulotrichopus
# 3              erebidae         erebidae             True        eudocima
# 4              erebidae         erebidae             True        eudocima
# ...                 ...              ...              ...             ...
# 373725     musophagidae     musophagidae             True         tauraco
# 373726     musophagidae     musophagidae             True         tauraco
# 373727     musophagidae     musophagidae             True         tauraco
# 373728     musophagidae     musophagidae             True         tauraco
# 373729     musophagidae     musophagidae             True         tauraco
#
#        genus_user_norm genus_row_match            species_pred_norm  \
# 0             eudocima           False           cerocala contraria
# 1             eudocima           False  chrysorithrum flavomaculata
# 2             eudocima           False      ulotrichopus marmoratus
# 3             eudocima            True           eudocima divitiosa
# 4             eudocima            True             eudocima colubra
# ...                ...             ...                          ...
# 373725        gallirex           False      tauraco porphyreolophus
# 373726        gallirex           False            tauraco hartlaubi
# 373727        gallirex           False        tauraco erythrolophus
# 373728        gallirex           False             tauraco fischeri
# 373729        gallirex           False            tauraco corythaix
#
#                species_user_norm species_row_match
# 0             eudocima divitiosa             False
# 1             eudocima divitiosa             False
# 2             eudocima divitiosa             False
# 3             eudocima divitiosa              True
# 4             eudocima divitiosa             False
# ...                          ...               ...
# 373725  gallirex porphyreolophus             False
# 373726  gallirex porphyreolophus             False
# 373727  gallirex porphyreolophus             False
# 373728  gallirex porphyreolophus             False
# 373729  gallirex porphyreolophus             False
#
# [373730 rows x 46 columns]

# %%
match_df = df[df["Falsely identified"]=="Match"]
match_df
# Out:
#                                     crop_file  \
# 0       obs_10003229_photo_114145431_box1.jpg
# 1       obs_10003229_photo_114145431_box1.jpg
# 2       obs_10003229_photo_114145431_box1.jpg
# 3       obs_10003229_photo_114145431_box1.jpg
# 4       obs_10003229_photo_114145431_box1.jpg
# ...                                       ...
# 373590  obs_99944557_photo_166725516_box2.jpg
# 373591  obs_99944557_photo_166725516_box2.jpg
# 373592  obs_99944557_photo_166725516_box2.jpg
# 373593  obs_99944557_photo_166725516_box2.jpg
# 373594  obs_99944557_photo_166725516_box2.jpg
#
#                                            crop_file_path  \
# 0       /rs1/researchers/a/amallav/results/outputs_cro...
# 1       /rs1/researchers/a/amallav/results/outputs_cro...
# 2       /rs1/researchers/a/amallav/results/outputs_cro...
# 3       /rs1/researchers/a/amallav/results/outputs_cro...
# 4       /rs1/researchers/a/amallav/results/outputs_cro...
# ...                                                   ...
# 373590  /rs1/researchers/a/amallav/results/outputs_cro...
# 373591  /rs1/researchers/a/amallav/results/outputs_cro...
# 373592  /rs1/researchers/a/amallav/results/outputs_cro...
# 373593  /rs1/researchers/a/amallav/results/outputs_cro...
# 373594  /rs1/researchers/a/amallav/results/outputs_cro...
#
#                             image_id Falsely identified  box_num  \
# 0       obs_10003229_photo_114145431              Match        1
# 1       obs_10003229_photo_114145431              Match        1
# 2       obs_10003229_photo_114145431              Match        1
# 3       obs_10003229_photo_114145431              Match        1
# 4       obs_10003229_photo_114145431              Match        1
# ...                              ...                ...      ...
# 373590  obs_99944557_photo_166725516              Match        2
# 373591  obs_99944557_photo_166725516              Match        2
# 373592  obs_99944557_photo_166725516              Match        2
# 373593  obs_99944557_photo_166725516              Match        2
# 373594  obs_99944557_photo_166725516              Match        2
#
#                             species     User_classified  same_species?  \
# 0                Cerocala contraria  Eudocima divitiosa          False
# 1       Chrysorithrum flavomaculata  Eudocima divitiosa          False
# 2           Ulotrichopus marmoratus  Eudocima divitiosa          False
# 3                Eudocima divitiosa  Eudocima divitiosa           True
# 4                  Eudocima colubra  Eudocima divitiosa          False
# ...                             ...                 ...            ...
# 373590                Anolis sagrei       Anolis sagrei           True
# 373591          Anolis carolinensis       Anolis sagrei          False
# 373592                 Anolis ustus       Anolis sagrei          False
# 373593            Anolis homolechis       Anolis sagrei          False
# 373594           Anolis terraealtae       Anolis sagrei          False
#
#         My analysis        common_name  ... order_row_match family_pred_norm  \
# 0               NaN                NaN  ...            True         erebidae
# 1               NaN                NaN  ...            True         erebidae
# 2               NaN                NaN  ...            True         erebidae
# 3               NaN                NaN  ...            True         erebidae
# 4               NaN                NaN  ...            True         erebidae
# ...             ...                ...  ...             ...              ...
# 373590          NaN        Brown anole  ...           False      dactyloidae
# 373591          NaN        Green anole  ...           False      dactyloidae
# 373592          NaN                NaN  ...           False      dactyloidae
# 373593          NaN       Habana anole  ...           False      dactyloidae
# 373594          NaN  Les saintes anole  ...           False      dactyloidae
#
#        family_user_norm family_row_match genus_pred_norm genus_user_norm  \
# 0              erebidae             True        cerocala        eudocima
# 1              erebidae             True   chrysorithrum        eudocima
# 2              erebidae             True    ulotrichopus        eudocima
# 3              erebidae             True        eudocima        eudocima
# 4              erebidae             True        eudocima        eudocima
# ...                 ...              ...             ...             ...
# 373590         anolidae            False          anolis          anolis
# 373591         anolidae            False          anolis          anolis
# 373592         anolidae            False          anolis          anolis
# 373593         anolidae            False          anolis          anolis
# 373594         anolidae            False          anolis          anolis
#
#        genus_row_match            species_pred_norm   species_user_norm  \
# 0                False           cerocala contraria  eudocima divitiosa
# 1                False  chrysorithrum flavomaculata  eudocima divitiosa
# 2                False      ulotrichopus marmoratus  eudocima divitiosa
# 3                 True           eudocima divitiosa  eudocima divitiosa
# 4                 True             eudocima colubra  eudocima divitiosa
# ...                ...                          ...                 ...
# 373590            True                anolis sagrei       anolis sagrei
# 373591            True          anolis carolinensis       anolis sagrei
# 373592            True                 anolis ustus       anolis sagrei
# 373593            True            anolis homolechis       anolis sagrei
# 373594            True           anolis terraealtae       anolis sagrei
#
#        species_row_match
# 0                  False
# 1                  False
# 2                  False
# 3                   True
# 4                  False
# ...                  ...
# 373590              True
# 373591             False
# 373592             False
# 373593             False
# 373594             False
#
# [269785 rows x 46 columns]

# %%
user_col = 'user_phylum'
match_col = 'same_species?'
status_col = 'Falsely identified'

# %%
s = df.copy()
s['match_norm'] = s[match_col].astype(str).str.strip().str.lower()
s['status_norm'] = s[status_col].astype(str).str.strip().str.lower()
s
# Out:
#                                     crop_file  \
# 0       obs_10003229_photo_114145431_box1.jpg
# 1       obs_10003229_photo_114145431_box1.jpg
# 2       obs_10003229_photo_114145431_box1.jpg
# 3       obs_10003229_photo_114145431_box1.jpg
# 4       obs_10003229_photo_114145431_box1.jpg
# ...                                       ...
# 373725  obs_99990956_photo_166796345_box2.jpg
# 373726  obs_99990956_photo_166796345_box2.jpg
# 373727  obs_99990956_photo_166796345_box2.jpg
# 373728  obs_99990956_photo_166796345_box2.jpg
# 373729  obs_99990956_photo_166796345_box2.jpg
#
#                                            crop_file_path  \
# 0       /rs1/researchers/a/amallav/results/outputs_cro...
# 1       /rs1/researchers/a/amallav/results/outputs_cro...
# 2       /rs1/researchers/a/amallav/results/outputs_cro...
# 3       /rs1/researchers/a/amallav/results/outputs_cro...
# 4       /rs1/researchers/a/amallav/results/outputs_cro...
# ...                                                   ...
# 373725  /rs1/researchers/a/amallav/results/outputs_cro...
# 373726  /rs1/researchers/a/amallav/results/outputs_cro...
# 373727  /rs1/researchers/a/amallav/results/outputs_cro...
# 373728  /rs1/researchers/a/amallav/results/outputs_cro...
# 373729  /rs1/researchers/a/amallav/results/outputs_cro...
#
#                             image_id Falsely identified  box_num  \
# 0       obs_10003229_photo_114145431              Match        1
# 1       obs_10003229_photo_114145431              Match        1
# 2       obs_10003229_photo_114145431              Match        1
# 3       obs_10003229_photo_114145431              Match        1
# 4       obs_10003229_photo_114145431              Match        1
# ...                              ...                ...      ...
# 373725  obs_99990956_photo_166796345           No Match        2
# 373726  obs_99990956_photo_166796345           No Match        2
# 373727  obs_99990956_photo_166796345           No Match        2
# 373728  obs_99990956_photo_166796345           No Match        2
# 373729  obs_99990956_photo_166796345           No Match        2
#
#                             species           User_classified  same_species?  \
# 0                Cerocala contraria        Eudocima divitiosa          False
# 1       Chrysorithrum flavomaculata        Eudocima divitiosa          False
# 2           Ulotrichopus marmoratus        Eudocima divitiosa          False
# 3                Eudocima divitiosa        Eudocima divitiosa           True
# 4                  Eudocima colubra        Eudocima divitiosa          False
# ...                             ...                       ...            ...
# 373725      Tauraco porphyreolophus  Gallirex porphyreolophus          False
# 373726            Tauraco hartlaubi  Gallirex porphyreolophus          False
# 373727        Tauraco erythrolophus  Gallirex porphyreolophus          False
# 373728             Tauraco fischeri  Gallirex porphyreolophus          False
# 373729            Tauraco corythaix  Gallirex porphyreolophus          False
#
#         My analysis            common_name  ... family_user_norm  \
# 0               NaN                    NaN  ...         erebidae
# 1               NaN                    NaN  ...         erebidae
# 2               NaN                    NaN  ...         erebidae
# 3               NaN                    NaN  ...         erebidae
# 4               NaN                    NaN  ...         erebidae
# ...             ...                    ...  ...              ...
# 373725          NaN  Purple-crested Turaco  ...     musophagidae
# 373726          NaN      Hartlaub's Turaco  ...     musophagidae
# 373727          NaN     Red-crested Turaco  ...     musophagidae
# 373728          NaN       Fischer's turaco  ...     musophagidae
# 373729          NaN          Knysna turaco  ...     musophagidae
#
#        family_row_match genus_pred_norm genus_user_norm genus_row_match  \
# 0                  True        cerocala        eudocima           False
# 1                  True   chrysorithrum        eudocima           False
# 2                  True    ulotrichopus        eudocima           False
# 3                  True        eudocima        eudocima            True
# 4                  True        eudocima        eudocima            True
# ...                 ...             ...             ...             ...
# 373725             True         tauraco        gallirex           False
# 373726             True         tauraco        gallirex           False
# 373727             True         tauraco        gallirex           False
# 373728             True         tauraco        gallirex           False
# 373729             True         tauraco        gallirex           False
#
#                   species_pred_norm         species_user_norm  \
# 0                cerocala contraria        eudocima divitiosa
# 1       chrysorithrum flavomaculata        eudocima divitiosa
# 2           ulotrichopus marmoratus        eudocima divitiosa
# 3                eudocima divitiosa        eudocima divitiosa
# 4                  eudocima colubra        eudocima divitiosa
# ...                             ...                       ...
# 373725      tauraco porphyreolophus  gallirex porphyreolophus
# 373726            tauraco hartlaubi  gallirex porphyreolophus
# 373727        tauraco erythrolophus  gallirex porphyreolophus
# 373728             tauraco fischeri  gallirex porphyreolophus
# 373729            tauraco corythaix  gallirex porphyreolophus
#
#        species_row_match match_norm status_norm
# 0                  False      false       match
# 1                  False      false       match
# 2                  False      false       match
# 3                   True       true       match
# 4                  False      false       match
# ...                  ...        ...         ...
# 373725             False      false    no match
# 373726             False      false    no match
# 373727             False      false    no match
# 373728             False      false    no match
# 373729             False      false    no match
#
# [373730 rows x 48 columns]

# %%
# counts for exact statuses (case-insensitive)
match_counts = s[s['match_norm'] == 'true'].groupby(s[user_col].fillna('Unknown')).size()
no_match_counts = s[s['status_norm'] == 'no match'].groupby(s[user_col].fillna('Unknown')).size()
total_counts = match_counts + no_match_counts
match_counts, no_match_counts, total_counts
# Out:
# (user_phylum
#  Annelida              23
#  Arthropoda         14541
#  Ascomycota           113
#  Basidiomycota        140
#  Chordata           15735
#  Cnidaria              24
#  Echinodermata        101
#  Mollusca             302
#  Nemertea               6
#  Ochrophyta             5
#  Onychophora           56
#  Platyhelminthes       28
#  Proteobacteria         6
#  Tracheophyta        8097
#  dtype: int64,
#  user_phylum
#  Annelida                  95
#  Arthropoda             40985
#  Ascomycota              5515
#  Basidiomycota            610
#  Chordata               31915
#  Cnidaria                 335
#  Echinodermata            205
#  Entomophthoromycota      310
#  Mollusca                1025
#  Mycetozoa                 85
#  Onychophora              290
#  Oomycota                  60
#  Pisuviricota               5
#  Platyhelminthes          155
#  Proteobacteria            15
#  Tracheophyta           22340
#  dtype: int64,
#  user_phylum
#  Annelida                 118.0
#  Arthropoda             55526.0
#  Ascomycota              5628.0
#  Basidiomycota            750.0
#  Chordata               47650.0
#  Cnidaria                 359.0
#  Echinodermata            306.0
#  Entomophthoromycota        NaN
#  Mollusca                1327.0
#  Mycetozoa                  NaN
#  Nemertea                   NaN
#  Ochrophyta                 NaN
#  Onychophora              346.0
#  Oomycota                   NaN
#  Pisuviricota               NaN
#  Platyhelminthes          183.0
#  Proteobacteria            21.0
#  Tracheophyta           30437.0
#  dtype: float64)

# %%
summary = pd.DataFrame({
    'user_phylum': total_counts.index,
    'match_count': match_counts.reindex(total_counts.index, fill_value=0).astype(int).values,
    'no_match_count': no_match_counts.reindex(total_counts.index, fill_value=0).astype(int).values,
    'total_count': total_counts.values
})

# %%
summary['pct_match'] = (summary['match_count'] / summary['total_count'] * 100).round(2)
summary['pct_no_match'] = (summary['no_match_count'] / summary['total_count'] * 100).round(2)

summary = summary.sort_values('total_count', ascending=False).reset_index(drop=True)
summary
# Out:
#             user_phylum  match_count  no_match_count  total_count  pct_match  \
# 0            Arthropoda        14541           40985      55526.0      26.19
# 1              Chordata        15735           31915      47650.0      33.02
# 2          Tracheophyta         8097           22340      30437.0      26.60
# 3            Ascomycota          113            5515       5628.0       2.01
# 4              Mollusca          302            1025       1327.0      22.76
# 5         Basidiomycota          140             610        750.0      18.67
# 6              Cnidaria           24             335        359.0       6.69
# 7           Onychophora           56             290        346.0      16.18
# 8         Echinodermata          101             205        306.0      33.01
# 9       Platyhelminthes           28             155        183.0      15.30
# 10             Annelida           23              95        118.0      19.49
# 11       Proteobacteria            6              15         21.0      28.57
# 12  Entomophthoromycota            0             310          NaN        NaN
# 13            Mycetozoa            0              85          NaN        NaN
# 14             Nemertea            6               0          NaN        NaN
# 15           Ochrophyta            5               0          NaN        NaN
# 16             Oomycota            0              60          NaN        NaN
# 17         Pisuviricota            0               5          NaN        NaN
#
#     pct_no_match
# 0          73.81
# 1          66.98
# 2          73.40
# 3          97.99
# 4          77.24
# 5          81.33
# 6          93.31
# 7          83.82
# 8          66.99
# 9          84.70
# 10         80.51
# 11         71.43
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
